# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ds1 = pd.read_csv('Customer Bill Detail.csv')
#ds['Dish Details'].value_counts()
ds1[8373:8375]
# Out:
#                Type        Date   Bill Number  Discount  Subtotal  \
# 8373  Home Delivery  2018-09-22  200837723936       0.0     169.0
# 8374  Home Delivery  2018-09-22  200837724264      77.4      51.6
#
#       Delivery Amt  Total Bill        Channel   Customer ID  \
# 8373             0         169  Zomato Online  245831671237
# 8374             0          52  Zomato Online  138626187589
#
#                                           Dish Details
# 8373  Hyderabadi Chicken Fry Piece Biryani (QTY-1.000)
# 8374                         Chicken Tikka (QTY-1.000)

# %% [markdown]
# ### In row 8374 as shown above, the Discount has exceeded the subtotal which is not appropriate and that is out of place in data. The discount is 77.4 and the subtotal is just 52 so it is not appropriate data

# %%
ds3 = pd.read_csv('Market Pricing.csv')
dp=ds3[['Restaurant','Menu Item']][1904:2085]
dp
# Out:
#      Restaurant                                  Menu Item
# 1904       Goli                         Chicken Curry Full
# 1905       Goli                         Chicken curry Half
# 1906       Goli                        Butter Chicken Half
# 1907       Goli                        Butter Chicken Full
# 1908       Goli                      Tandoori Chicken Half
# 1909       Goli                      Tandoori Chicken Full
# 1910       Goli  Hyderabadi Chicken Fry Piece Biryani Half
# 1911       Goli  Hyderabadi Chicken Fry Piece Biryani Full
# 1912       Goli         Hyderabadi Mutton Dum Biryani Full
# 1913       Goli         Hyderabadi Mutton Dum Biryani Half
# 1914       Goli                           Rajma Rice Combo
# 1915       Goli                           Chole Rice Combo
# 1916       Goli                    Lemon Rice Combo [Full]
# 1917       Goli                               Veg Platter
# 1918       Goli                      Non Veg Royal Platter
# ...

# %%
dp['Menu Item'].value_counts()
# Out:
# Butter Chicken Half                          2
# Hyderabadi Chicken Fry Piece Biryani Full    2
# Chicken Malai Tikka Full                     2
# Tandoori Chicken Full                        2
# Hyderabadi Mutton Dum Biryani Half           2
# Hyderabadi Mutton Dum Biryani Full           2
# Chicken Curry Full                           2
# Butter Chicken Full                          2
# Chicken Pahadi Tikka Full                    2
# Chicken Pahadi Tikka Half                    2
# Tandoori Chicken Half                        2
# Chicken Malai Tikka Half                     2
# Hyderabadi Chicken Fry Piece Biryani Half    2
# Chole Rice Combo                             1
# Tandoori Chicken Kali Mirch Full             1
# Chicken Home Style Half                      1
# Cheese Garlic Paratha                        1
# Dhaniya Chicken Half                         1
# Egg Curry                                    1
# Paneer Garlic Tikka                          1
# ...

# %% [markdown]
# ### In goli's Menu some dishes are listed twice which is also not appropriate
