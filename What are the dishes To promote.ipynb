# %% [markdown]
# ### Dishes to promote

# %% [markdown]
# ### The dishes which are ordered in the highest frequency,the uniques dishes that exist only in Goli's restaurant and the dishes which are most liked in goli's restaurant should be promoted beacuse those are already liked by people and therfore it has a high probability that new customers will also like the same and that can ensures with high probability that if its taste suites the new customer he will probably like to visit again and that can increase the earning of Mr Goli. The dishes which are unique in the Goli's Restaurant are kind of a signature dishes that will tempt the customers to try for at least once.

# %% [markdown]
# ### dishes which peope love in Goli's Restaurant

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ds = pd.read_csv('Market Pricing.csv')
print(type(ds))
#ds['Dish Name'].value_counts()
#ds[:20]
#ds.tail(n=5000)
ds[1904:2000][['What people love here','Restaurant']]
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                                   What people love here Restaurant
# 1904  Butter Chicken, Fish Tikka, Hyderabadi Biryani...       Goli
# 1905  Butter Chicken, Fish Tikka, Hyderabadi Biryani...       Goli
# 1906  Butter Chicken, Fish Tikka, Hyderabadi Biryani...       Goli
# 1907  Butter Chicken, Fish Tikka, Hyderabadi Biryani...       Goli
# 1908  Butter Chicken, Fish Tikka, Hyderabadi Biryani...       Goli
# 1909  Butter Chicken, Fish Tikka, Hyderabadi Biryani...       Goli
# 1910  Butter Chicken, Fish Tikka, Hyderabadi Biryani...       Goli
# 1911  Butter Chicken, Fish Tikka, Hyderabadi Biryani...       Goli
# 1912  Butter Chicken, Fish Tikka, Hyderabadi Biryani...       Goli
# 1913  Butter Chicken, Fish Tikka, Hyderabadi Biryani...       Goli
# 1914  Butter Chicken, Fish Tikka, Hyderabadi Biryani...       Goli
# 1915  Butter Chicken, Fish Tikka, Hyderabadi Biryani...       Goli
# ...

# %% [markdown]
# ### Dishes with the highest frequenct in the Goli's Restaurant

# %%
ds3 = pd.read_csv('Market Pricing.csv')
dp=ds[['Restaurant','Menu Item']][1904:2085]
dp
# Out:
#      Restaurant                                  Menu Item
# 1904       Goli                         Chicken Curry Full
# 1905       Goli                         Chicken curry Half
# 1906       Goli                        Butter Chicken Half
# 1907       Goli                        Butter Chicken Full
# 1908       Goli                      Tandoori Chicken Half
# 1909       Goli                      Tandoori Chicken Full
# 1910       Goli  Hyderabadi Chicken Fry Piece Biryani Half
# 1911       Goli  Hyderabadi Chicken Fry Piece Biryani Full
# 1912       Goli         Hyderabadi Mutton Dum Biryani Full
# 1913       Goli         Hyderabadi Mutton Dum Biryani Half
# 1914       Goli                           Rajma Rice Combo
# 1915       Goli                           Chole Rice Combo
# 1916       Goli                    Lemon Rice Combo [Full]
# 1917       Goli                               Veg Platter
# 1918       Goli                      Non Veg Royal Platter
# ...

# %%
ds2 = pd.read_csv('Customer Order Item Details.csv')
ds2['Dish Name'].value_counts()
# Out:
# Hyderabadi Chicken Fry Piece Biryani                                       1329
# Tandoori Roti                                                              1262
# Chicken Curry                                                               958
# Butter Chicken                                                              787
# Tandoori Roti Butter                                                        716
# Hyderabadi Mutton Dum Biryani                                               584
# Tandoori Chicken                                                            521
# Egg Curry                                                                   403
# Butter nan                                                                  398
# Kadhai Chicken                                                              337
# water bottle                                                                325
# Lachchha Paratha                                                            325
# ...

# %% [markdown]
# ### Hyderabadi Chicken Fry Piece Biryani has the highest frequency in the menu item of Goli followed by Chicken Curry and Butter Chicken

# %% [markdown]
# ### unique dishes that exist only in Goli's Restaurant

# %%
ds = pd.read_csv('Market Pricing.csv')
dp=ds[['Restaurant','Menu Item']][1904:2085]
dm=ds['Menu Item'][4859:5009].value_counts()
dm
# Out:
# Dhaba Meat (Full 4 Pieces)              1
# Pyaz Mirch Di Roti                      1
# Missi Roti                              1
# Makai Malai Seekh                       1
# Tandoori Roti                           1
# Butter Naan                             1
# Plain Rice                              1
# Rooh E Rabri                            1
# Pepsi [500 ml]                          1
# Chilly Garlic Moongfali                 1
# Bhuna Murg (Half 2 Pieces)              1
# Ice Cream                               1
# Masala Papad                            1
# Jeera Rice                              1
# Bharwa Mushroom                         1
# Dum Aloo                                1
# Paneer Paratha                          1
# Murg Makhani (Full 4 Pieces)            1
# Mutton Rogan Josh (Half 2 Pieces)       1
# Afgani Chicken (Full)                   1
# Chicken Paratha                         1
# Lahsooni Palak                          1
# ...
