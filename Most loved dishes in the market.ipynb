# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ds3 = pd.read_csv('Market Pricing.csv')
#dp=ds3['Restaurant'].unique()
#dp1=ds3['What people love here'].unique()
ds3
# Out:
#      Restaurant        Menu Header                            Menu Item Rate  \
# 0          12 e       Veg Starters                         Paneer Tikka  190
# 1          12 e       Veg Starters               Paneer Peshawari Tikka  200
# 2          12 e       Veg Starters               Paneer Kalimirch Tikka  190
# 3          12 e       Veg Starters                   Paneer Malai Tikka  200
# 4          12 e       Veg Starters            Cheese Chilly Onion Kabah  160
# 5          12 e       Veg Starters                       Mushroom Tikka  160
# 6          12 e       Veg Starters                    Subz Sholai Kabab  160
# 7          12 e   Non Veg Starters                           Murg Tikka  240
# 8          12 e   Non Veg Starters                     Murg Malai Tikka  250
# 9          12 e   Non Veg Starters                    Murg Pahadi Tikka  240
# 10         12 e   Non Veg Starters                    Murg Afgani Tikka  250
# ...

# %%
final=ds3.drop(['Menu Header','Menu Item','Rate'],axis='columns')
final=final.rename(columns={"What people love here":"Dishes_most_loved",})
#final.set_index('Restaurant',inplace=True)
a=final.Restaurant.unique()
#a=np.array(r,dtype=int)
print(a)
# Out:
# ['12 e' 'Alol' 'Apn)' 'Awen' 'Behi' 'CHIE' 'CULT' 'Flas' 'Foos' 'Foot'
#  'Galt' 'GFCy' 'Goli' 'Hotr' 'Kebs' 'Kebl' 'Kukb' 'Last' 'Line' 'Macp'
#  'Mano' 'Misf' 'Mr.s' 'Naft' 'Noon' 'Pini' 'Pisa' 'Prij' 'Regt' 'Roti'
#  'Saji' 'Sint' 'Sinb' 'Thei' 'Zaia']

# %% [markdown]
# ### the dishes which are most loved in the restaurants given above are

# %%
b=final.Dishes_most_loved.unique()
print(b)
# Out:
# ['Butter Chicken, Chicken Biryani' 'Fish Tikka' nan
#  'Paneer Tikka, Dal Tadka' 'Gulab Jamun, Rice, Chicken Biryani'
#  'Shawarma, Chicken Taka Tak, Barbeque Chicken, Chicken Grill, Chicken Tenders, Chicken Shawarama, Hyderabadi Chicken'
#  'Dal Makhani, Nalli Nihari'
#  'Butter Chicken, Tandoori Chicken, Dum Biryani' 'Biryani'
#  'Dal Makhani, Panneer Butter Masala, Butter Chicken, Naan'
#  'Butter Chicken, Fish Tikka, Hyderabadi Biryani, Chicken Dum Biryani, Tandoori Chicken, Chicken Tikka, Raita'
#  'Butter Chicken, Chicken Biryani, Tandoori Chicken'
#  'Tandoori Chicken, Rumali Roti, Chicken Tikka Masala, Butter Chicken, Naan'
#  'Jumbo Prawns, Dal Makhani, Paan Ice Cream, Chicken Tikka, Salads, Dum Biryani, Crispy Corn'
#  'Butter Chicken, Rice, Keema Kaleji, Mutton Bhuna, Mutton Curry'
#  'Vegetable Biryani, Chicken Biryani, Shawarma, Kiwi Mojito, Mint Mojito, Seekh Kebab, Fish'
#  'Egg Curry, Roti, Chicken Sukha'
# ...

# %% [markdown]
# ### These are the most loved dishes in the market
